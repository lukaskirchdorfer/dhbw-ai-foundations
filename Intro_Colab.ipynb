# %% [markdown]
# ## 1. Kurzübersicht Google Colab

# %% [markdown]
# **Advantages**:
#
# - Free of charge
# - No setup required
# - Access to GPUs/TPUs
# - Easy sharing
#
# **Disadvantages**:
#
# - Runtime limited to a maximum of 12 hours (in the free version)
#
# **Use cases**:
#
# - Visualize und understand data
# - Training neural networks on GPUs/TPUs
# - Dissemination of AI research
# - Creation of guides/tutorials

# %% [markdown]
# ## 1.1 Simple Code Example

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## 1.2 Text Examples

# %% [markdown]
# # H1
# ## H2
# ### H3
# #### H4
#
#
#
# - Key point 1
# - Key point 2
#
#
# Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet. Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet.

# %% [markdown]
# ## 1.3 Visualizations

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 100 + np.random.randn(200)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 100, where=(ys > 100), facecolor='b', alpha=0.7)

plt.title("Example Visualization")
plt.show()

# %% [markdown]
# ## 1.4 GPU (Graphics Processing Unit) vs. CPU (Central Processing Unit)

# %% [markdown]
# - 1) Click on the arrow in the top right
# - 2) Select "Change runtime type"
# - 3) Select T4 GPU
# - 4) Save
#
# Now you are connected to a GPU

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)

print(gpu_info)
# Out:
# Sat Aug 17 10:58:08 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...
